# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
zip_file_name_open = 'h_eval_working.zip'

# %%
scene_filename = 'bedroom_04.h5'

# %%
# !cp -r '/content/gdrive/MyDrive/ESE_650_Project/{zip_file_name_open}' '/content/'

# %%
# !cp -r '/content/gdrive/MyDrive/ESE_650_Project/{scene_filename}' '/content/'

# %%
# %%capture
# !unzip {zip_file_name_open}

# %%
# !cp -r '/content/content/visual-navigation-agent-pytorch-master' '/content'

# %%
# !rm -r '/content/content'

# %%
# %%capture
# !pip install ai2thor

# %%
# %%capture
# !pip install folium==0.2.1

# %%
# from ai2thor.controller import Controller
# controller = Controller()
# event = controller.step("MoveAhead")

# %%
# zip_file_name_save = 'h_eval_working_2.zip'

# %%
# %%capture
# !zip -r {zip_file_name} 'visual-navigation-agent-pytorch-master'
# Out:
#   adding: visual-navigation-agent-pytorch-master/ (stored 0%)
#   adding: visual-navigation-agent-pytorch-master/tf-checkpoint-10000000.p (deflated 8%)
#   adding: visual-navigation-agent-pytorch-master/pytorch-old-2600k.csv (deflated 64%)
#   adding: visual-navigation-agent-pytorch-master/.vscode/ (stored 0%)
#   adding: visual-navigation-agent-pytorch-master/.vscode/launch.json (deflated 80%)
#   adding: visual-navigation-agent-pytorch-master/.vscode/settings.json (deflated 17%)
#   adding: visual-navigation-agent-pytorch-master/hitting_times_notrequired.py (deflated 68%)
#   adding: visual-navigation-agent-pytorch-master/checkpoint-1400000.pth (deflated 31%)
#   adding: visual-navigation-agent-pytorch-master/explorer.py (deflated 62%)
#   adding: visual-navigation-agent-pytorch-master/bedroom_04-151.png (deflated 0%)
#   adding: visual-navigation-agent-pytorch-master/kitchen_02-261.png (deflated 0%)
#   adding: visual-navigation-agent-pytorch-master/newmetric_tf.csv (deflated 56%)
#   adding: visual-navigation-agent-pytorch-master/requirements.txt (stored 0%)
#   adding: visual-navigation-agent-pytorch-master/eval.py (deflated 55%)
#   adding: visual-navigation-agent-pytorch-master/agent/ (stored 0%)
#   adding: visual-navigation-agent-pytorch-master/agent/training_thread.py (deflated 72%)
#   adding: visual-navigation-agent-pytorch-master/agent/environment/ (stored 0%)
#   adding: visual-navigation-agent-pytorch-master/agent/environment/environment.py (deflated 52%)
#   adding: visual-navigation-agent-pytorch-master/agent/environment/graph.py (deflated 49%)
#   adding: visual-navigation-agent-pytorch-master/agent/environment/thor.py (deflated 62%)
#   adding: visual-navigation-agent-pytorch-master/agent/environment/ai2thor.py (deflated 73%)
#   adding: visual-navigation-agent-pytorch-master/agent/environment/__init__.py (deflated 65%)
#   adding: visual-navigation-agent-pytorch-master/agent/environment/__pycache__/ (stored 0%)
#   adding: visual-navigation-agent-pytorch-master/agent/environment/__pycache__/environment.cpython-37.pyc (deflated 50%)
#   adding: visual-navigation-agent-pytorch-master/agent/environment/__pycache__/__init__.cpython-37.pyc (deflated 53%)
#   adding: visual-navigation-agent-pytorch-master/agent/environment/__pycache__/ai2thor.cpython-37.pyc (deflated 50%)
#   adding: visual-navigation-agent-pytorch-master/agent/resnet.py (deflated 65%)
#   adding: visual-navigation-agent-pytorch-master/agent/scene_loader.py (deflated 70%)
#   adding: visual-navigation-agent-pytorch-master/agent/__init__.py (stored 0%)
#   adding: visual-navigation-agent-pytorch-master/agent/app.py (stored 0%)
#   adding: visual-navigation-agent-pytorch-master/agent/replay.py (deflated 58%)
#   adding: visual-navigation-agent-pytorch-master/agent/utils.py (deflated 62%)
#   adding: visual-navigation-agent-pytorch-master/agent/network.py (deflated 70%)
#   adding: visual-navigation-agent-pytorch-master/agent/input.py (deflated 48%)
#   adding: visual-navigation-agent-pytorch-master/agent/__pycache__/ (stored 0%)
#   adding: visual-navigation-agent-pytorch-master/agent/__pycache__/training_thread.cpython-37.pyc (deflated 46%)
#   adding: visual-navigation-agent-pytorch-master/agent/__pycache__/replay.cpython-37.pyc (deflated 44%)
#   adding: visual-navigation-agent-pytorch-master/agent/__pycache__/training.cpython-37.pyc (deflated 51%)
#   adding: visual-navigation-agent-pytorch-master/agent/__pycache__/__init__.cpython-37.pyc (deflated 22%)
#   adding: visual-navigation-agent-pytorch-master/agent/__pycache__/resnet.cpython-37.pyc (deflated 40%)
#   adding: visual-navigation-agent-pytorch-master/agent/__pycache__/network.cpython-37.pyc (deflated 51%)
#   adding: visual-navigation-agent-pytorch-master/agent/__pycache__/utils.cpython-37.pyc (deflated 39%)
#   adding: visual-navigation-agent-pytorch-master/agent/__pycache__/evaluation.cpython-37.pyc (deflated 45%)
#   adding: visual-navigation-agent-pytorch-master/agent/__pycache__/optim.cpython-37.pyc (deflated 39%)
#   adding: visual-navigation-agent-pytorch-master/agent/training.py (deflated 72%)
#   adding: visual-navigation-agent-pytorch-master/agent/optim.py (deflated 62%)
#   adding: visual-navigation-agent-pytorch-master/agent/evaluation.py (deflated 70%)
#   adding: visual-navigation-agent-pytorch-master/data-tensorflow.csv (deflated 61%)
#   adding: visual-navigation-agent-pytorch-master/checkpoint-1600000.pth (deflated 28%)
#   adding: visual-navigation-agent-pytorch-master/Untitled.ipynb (deflated 87%)
#   adding: visual-navigation-agent-pytorch-master/deep-reactive-agent-pytorch.zip (stored 0%)
#   adding: visual-navigation-agent-pytorch-master/living_room_08-353.png (deflated 0%)
#   adding: visual-navigation-agent-pytorch-master/data.csv (deflated 52%)
#   adding: visual-navigation-agent-pytorch-master/LICENSE (deflated 40%)
#   adding: visual-navigation-agent-pytorch-master/.dockerignore (deflated 5%)
#   adding: visual-navigation-agent-pytorch-master/docker-compose.yaml (deflated 48%)
#   adding: visual-navigation-agent-pytorch-master/newmetric_pythorch_16.csv (deflated 51%)
#   adding: visual-navigation-agent-pytorch-master/train.py (deflated 60%)
#   adding: visual-navigation-agent-pytorch-master/newmetric-tf-scene2.csv (deflated 53%)
#   adding: visual-navigation-agent-pytorch-master/fcntl.py (deflated 48%)
#   adding: visual-navigation-agent-pytorch-master/bathroom_02-179.png (deflated 0%)
#   adding: visual-navigation-agent-pytorch-master/h5py/ (stored 0%)
#   adding: visual-navigation-agent-pytorch-master/h5py/h5f.pyx (stored 0%)
#   adding: visual-navigation-agent-pytorch-master/Dockerfile (deflated 49%)
#   adding: visual-navigation-agent-pytorch-master/.ipynb_checkpoints/ (stored 0%)
#   adding: visual-navigation-agent-pytorch-master/weights.p (deflated 8%)
#   adding: visual-navigation-agent-pytorch-master/weights.pkl (deflated 8%)
#   adding: visual-navigation-agent-pytorch-master/.gitignore (deflated 47%)
#   adding: visual-navigation-agent-pytorch-master/graph.p (deflated 97%)
#   adding: visual-navigation-agent-pytorch-master/weights.pth (deflated 8%)
#   adding: visual-navigation-agent-pytorch-master/newmetric-pth16-scene2.csv (deflated 49%)
#   adding: visual-navigation-agent-pytorch-master/README.md (deflated 55%)
#   adding: visual-navigation-agent-pytorch-master/pytorch-old-2400k.csv (deflated 59%)

# %%
# !cp {zip_file_name} '/content/gdrive/MyDrive/ESE_650_Project'
