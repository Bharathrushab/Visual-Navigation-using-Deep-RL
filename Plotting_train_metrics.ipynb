# %% [markdown]
# # Train metrics visualization

# %% [markdown]
# Train metrics can be accessed in below link till 10th May 2022 after which the link expires.
#
# Please go to the link below and expand the 'runs/train' section
#
# https://wandb.ai/anony-mouse-250290/uncategorized/runs/1mt1ylb6

# %% [markdown]
# # Visualization code

# %%
# %%capture
! pip install wandb -qqq

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import wandb

# %%
wandb.init(anonymous="allow")
# Out:
# wandb: (1) Private W&B dashboard, no account required
# wandb: (2) Use an existing W&B account
# wandb: Enter your choice: 1
# wandb: You chose 'Private W&B dashboard, no account required'
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/wandb/run-20220503_232748-te3ltq3x</code>
# Syncing run <strong><a href="https://wandb.ai/anony-mouse-250290/uncategorized/runs/te3ltq3x?apiKey=d1bd2649be966d4603e45f788b160449e0d656ef" target="_blank">effortless-hill-1</a></strong> to <a href="https://wandb.ai/anony-mouse-250290/uncategorized?apiKey=d1bd2649be966d4603e45f788b160449e0d656ef" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# ...

# %%
wandb.tensorboard.patch(root_logdir='./runs')

# %%
# !wandb sync --sync-tensorboard './runs'

# %%
# !wandb sync './runs'
# Out:
# Found 1 tfevent files in /content
# Syncing: https://wandb.ai/anony-mouse-250290/uncategorized/runs/1mt1ylb6 ...

# %%
run = wandb.init()
# Out:
# wandb: Currently logged in as: anony-mouse-250290. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/wandb/run-20220503_233119-35zoewue</code>
# Syncing run <strong><a href="https://wandb.ai/anony-mouse-250290/uncategorized/runs/35zoewue?apiKey=d1bd2649be966d4603e45f788b160449e0d656ef" target="_blank">swift-pyramid-4</a></strong> to <a href="https://wandb.ai/anony-mouse-250290/uncategorized?apiKey=d1bd2649be966d4603e45f788b160449e0d656ef" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %%
wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# ...
# Synced <strong style="color:#cdcd00">azure-valley-3</strong>: <a href="https://wandb.ai/anony-mouse-250290/uncategorized/runs/6b3hwixv?apiKey=d1bd2649be966d4603e45f788b160449e0d656ef" target="_blank">https://wandb.ai/anony-mouse-250290/uncategorized/runs/6b3hwixv?apiKey=d1bd2649be966d4603e45f788b160449e0d656ef</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220503_233058-6b3hwixv/logs</code>
